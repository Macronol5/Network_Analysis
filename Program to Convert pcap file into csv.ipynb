# %%
#API Call
import virustotal_python
from pprint import pprint
from base64 import urlsafe_b64encode

url = "google.com"

with virustotal_python.Virustotal("2e6c19c891717196bcadb5c81dd8d7a9f3c00c3ca888cba147fcaf31111c6cfc") as vtotal:
    try:
        resp = vtotal.request("urls", data={"url": url}, method="POST")
        # Safe encode URL in base64 format
        # https://developers.virustotal.com/reference/url
        url_id = urlsafe_b64encode(url.encode()).decode().strip("=")
        report = vtotal.request(f"urls/{url_id}")
        pprint(report.object_type)
        pprint(report.data)
    except virustotal_python.VirustotalError as err:
        print(f"Failed to send URL: {url} for analysis and get the report: {err}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #API Call
# ----> 2 import virustotal_python
#       3 from pprint import pprint
#       4 from base64 import urlsafe_b64encode
#
# ModuleNotFoundError: No module named 'virustotal_python'

# %%
#Python program to read the data from pcap file and analysis the destination address for malicious.
from scapy.all import *
import csv
import virustotal_python
from pprint import pprint
from base64 import urlsafe_b64encode

# Read the PCAP file
packets = rdpcap('file3.pcap')

# Print the summary info for each packet
with open('savefile.csv', 'w', newline='') as csvfile:
    fieldnames = ['Time', 'Source IP','Source Port', 'Destination','Destination Port','Harmless','Malicious','Suspicious','Undetected']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
        
    for packet in packets:
        print(packet.summary())
        if packet.summary()[-1] == "w":
            (source,destination) = (packet.summary().split()[5],packet.summary().split()[7])
            print(destination.split(":")[0])
            url=destination.split(":")[0]
            with virustotal_python.Virustotal("2e6c19c891717196bcadb5c81dd8d7a9f3c00c3ca888cba147fcaf31111c6cfc") as vtotal:
                try:
                    resp=vtotal.request("urls", data={"url":url}, method="POST")
                    url_id = urlsafe_b64encode(url.encode()).decode().strip("=")
                    report = vtotal.request(f"urls/{url_id}")
                    result = report.data['attributes']['last_analysis_stats']
                    print(result)
                except virustotal_python.VirustotalError as err:
                    result = f"Failed to send URL:{url} for analysis and get the report: {err}"
                    
            row = {
                    'Time': packet.time,
                    'Source IP': source.split(":")[0],
                    'Source Port': source.split(":")[1],
                    'Destination': destination.split(":")[0],      
                    'Destination Port': destination.split(":")[1],
                    'Harmless': result['harmless'],
                    'Malicious': result['malicious'],
                    'Suspicious': result['suspicious'],
                    'Undetected': result['undetected']
            }
            writer.writerow(row)
# Out:
# Ether / IP / TCP 192.168.27.51:38157 > 102.39.110.48:53411 S
# Ether / IP / TCP 192.168.27.51:38047 > 35.186.224.25:https A / Raw
# 35.186.224.25
# {'harmless': 76, 'malicious': 1, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / TCP 35.186.224.25:https > 192.168.27.51:38047 A
# Ether / IP / TCP 192.168.27.51:37939 > 54.77.96.221:https A / Raw
# 54.77.96.221
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.25.148:38129 > 239.255.255.250:ssdp / Raw
# 239.255.255.250
# {'harmless': 73, 'malicious': 3, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 35.83.87.190:https > 192.168.27.51:37567 PA / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.25.148:38129 > 239.255.255.250:ssdp / Raw
# 239.255.255.250
# {'harmless': 73, 'malicious': 3, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / IP / TCP 192.168.27.51:37567 > 35.83.87.190:https A
# Ether / IP / UDP 192.168.26.231:netbios_ns > 192.168.27.255:netbios_ns / NBNSQueryRequest
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / IP / TCP 54.77.96.221:https > 192.168.27.51:37939 A
# Ether / IP / UDP 192.168.25.148:38129 > 239.255.255.250:ssdp / Raw
# 239.255.255.250
# {'harmless': 73, 'malicious': 3, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / IP / TCP 192.168.27.51:38157 > 102.39.110.48:53411 S
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.143 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / IP / TCP 34.235.195.88:https > 192.168.27.51:38156 SA
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38149 A / Padding
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38149 PA / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38142 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38142 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https A
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38142 A / Padding
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38142 PA / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https PA / Raw
# 35.197.154.200
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38142 > 35.197.154.200:https A
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38149 A / Padding
# Ether / IP / TCP 35.197.154.200:https > 192.168.27.51:38149 PA / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / IP / TCP 192.168.27.51:38149 > 35.197.154.200:https A
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / TCP 192.168.27.51:38157 > 102.39.110.48:53411 S
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:59009 > 142.250.193.99:https / Raw
# 142.250.193.99
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 142.250.193.99:https > 192.168.27.51:59009 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 79, 'malicious': 1, 'suspicious': 0, 'undetected': 9, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 79, 'malicious': 1, 'suspicious': 0, 'undetected': 9, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 79, 'malicious': 1, 'suspicious': 0, 'undetected': 9, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 79, 'malicious': 1, 'suspicious': 0, 'undetected': 9, 'timeout': 0}
# Ether / IP / UDP 8.8.4.4:https > 192.168.27.51:49736 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49736 > 8.8.4.4:https / Raw
# 8.8.4.4
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:53160 > 78.106.183.133:6881 / Raw
# 78.106.183.133
# {'harmless': 57, 'malicious': 0, 'suspicious': 0, 'undetected': 7, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.24.2 says 192.168.24.2 / Padding
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / ARP who has 192.168.27.42 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.27.42 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.27.42 says 192.168.24.2 / Padding
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP / DNS Qry "b'dns.google.'"
# Ether / IP / UDP / DNS Qry "b'dns.google.'"
# Ether / IP / UDP / DNS Ans
# Ether / IP / UDP / DNS Ans "8.8.8.8"
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.26.59 says 192.168.24.2 / Padding
# Ether / IP / UDP 192.168.27.51:49372 > 172.217.160.142:https / Raw
# 172.217.160.142
# {'harmless': 77, 'malicious': 1, 'suspicious': 0, 'undetected': 12, 'timeout': 0}
# Ether / IP / UDP 8.8.8.8:https > 192.168.27.51:51330 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / IP / UDP 192.168.27.51:51330 > 8.8.8.8:https / Raw
# 8.8.8.8
# {'harmless': 75, 'malicious': 2, 'suspicious': 0, 'undetected': 13, 'timeout': 0}
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# {'harmless': 76, 'malicious': 0, 'suspicious': 0, 'undetected': 14, 'timeout': 0}
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / ARP who has 192.168.25.255 says 192.168.24.2 / Padding
# Ether / IP / UDP 172.217.160.142:https > 192.168.27.51:49372 / Raw
# 192.168.27.51
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 40
#      31     except virustotal_python.VirustotalError as err:
#      32         result = f"Failed to send URL:{url} for analysis and get the report: {err}"
#      34 row = {
#      35         'Time': packet.time,
#      36         'Source IP': source.split(":")[0],
#      37         'Source Port': source.split(":")[1],
#      38         'Destination': destination.split(":")[0],
#      39         'Destination Port': destination.split(":")[1],
# ---> 40         'Harmless': result['harmless'],
#      41         'Malicious': result['malicious'],
#      42         'Suspicious': result['suspicious'],
#      43         'Undetected': result['undetected']
#      44 }
#      45 writer.writerow(row)
#
# TypeError: string indices must be integers, not 'str'

# %%
#Program to clear the csv file
f = open("savefile.csv", "w")
f.truncate()
f.close()
